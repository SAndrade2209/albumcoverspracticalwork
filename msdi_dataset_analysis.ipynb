# %% [markdown]
# ## Imports

# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import os
from collections import Counter
import h5py
import requests
import reverse_geocoder as rg
from utils.location_processor import LocationProcessor

# %% [markdown]
# ### Functions

# %%
def get_dataframes_from_msd(input_path, dataset_name):
    
    with h5py.File(input_path, 'r') as file:
        # Access the 'songs' dataset within the 'musicbrainz' group
        dataset = file[f'{dataset_name}/songs']
        
        # Convert the dataset to a NumPy array
        data_array = dataset[:]
        
        if dataset.dtype.fields is not None:
            column_names = dataset.dtype.names
            df = pd.DataFrame(data_array, columns=column_names)
        else:
            # If there are no named fields, create a default range of column names
            df = pd.DataFrame(data_array)

    return  df

# %%
def download_image(image_url, local_file_name):
    response = requests.get(image_url)
    if response.status_code == 200:
        with open(local_file_name, 'wb') as file:
            file.write(response.content)
        #print(f"Image downloaded successfully: {local_file_name}")
    else:
        print(f"Error: Failed to download image. Status code: {response.status_code}")

def save_msdi_images_from_dataframe(path, df):
    for index, row in df.iterrows():
        track_name = row['msd_track_id']
        album_index = row['album_index']
        image_url = row['image_url']
        local_file_name = f"{path}/{album_index}_{track_name}.png"
        download_image(image_url, local_file_name)

def save_mumu_images_from_dataframe(path, df):
    for index, row in df.iterrows():
        track_name = row['amazon_id']
        album_index = index
        image_url = row['imUrl']
        local_file_name = f"{path}/{album_index}_{track_name}.png"
        if index > 27115:
            download_image(image_url, local_file_name)

# %% [markdown]
# ### Million songs dataset pre processing
#
# Here we separated the different sub_datasets in the h5 file

# %%
msd_input_path = "input/msd_summary_file.h5"
musicbrainz_df = get_dataframes_from_msd(msd_input_path, 'musicbrainz')
analysis_df = get_dataframes_from_msd(msd_input_path, 'analysis')
metadata_df = get_dataframes_from_msd(msd_input_path, 'metadata')

# %% [markdown]
# Get the relevant columns and decode them

# %%
musicbrainz_df = musicbrainz_df[['year']]

analysis_df = analysis_df[['track_id']]
analysis_df['track_id'] = analysis_df['track_id'].str.decode('utf-8')

metadata_df = metadata_df[['artist_id', 'artist_name', 'release', 'song_id', 'title', 'artist_location','artist_latitude','artist_longitude']]
metadata_df['artist_id'] = metadata_df['artist_id'].str.decode('utf-8')
metadata_df['artist_name'] = metadata_df['artist_name'].str.decode('utf-8')
metadata_df['release'] = metadata_df['release'].str.decode('utf-8')
metadata_df['song_id'] = metadata_df['song_id'].str.decode('utf-8')
metadata_df['title'] = metadata_df['title'].str.decode('utf-8')
metadata_df['artist_location'] = metadata_df['artist_location'].str.decode('utf-8')

# %%
musicbrainz_df
# Out:
#         year
# 0       2003
# 1       1995
# 2       2006
# 3       2003
# 4          0
# ...      ...
# 999995     0
# 999996     0
# 999997     0
# 999998     0
# 999999  2004
#
# [1000000 rows x 1 columns]

# %%
analysis_df
# Out:
#                   track_id
# 0       TRMMMYQ128F932D901
# 1       TRMMMKD128F425225D
# 2       TRMMMRX128F93187D9
# 3       TRMMMCH128F425532C
# 4       TRMMMWA128F426B589
# ...                    ...
# 999995  TRYYYUS12903CD2DF0
# 999996  TRYYYJO128F426DA37
# 999997  TRYYYMG128F4260ECA
# 999998  TRYYYDJ128F9310A21
# 999999  TRYYYVU12903CD01E3
#
# [1000000 rows x 1 columns]

# %%
metadata_df
# Out:
#                  artist_id       artist_name  \
# 0       ARYZTJS1187B98C555  Faster Pussy cat
# 1       ARMVN3U1187FB3A1EB  Karkkiautomaatti
# 2       ARGEKB01187FB50750    Hudson Mohawke
# 3       ARNWYLR1187B9B2F9C       Yerba Brava
# 4       AREQDTE1269FB37231        Der Mystic
# ...                    ...               ...
# 999995  AR7Z4J81187FB3FC59      Kiko Navarro
# 999996  ART5FZD1187B9A7FCF     Kuldeep Manak
# 999997  ARZ3R6M1187B9AF750    Gabriel Le Mar
# 999998  ARCMCOK1187B9B1073             Elude
# 999999  AR7PLM21187B990D08             Texta
#
#                                      release             song_id  \
# 0                      Monster Ballads X-Mas  SOQMMHC12AB0180CB8
# 1                                Karkuteillä  SOVFVAK12A8C1350D9
# 2                                     Butter  SOGTUKN12AB017F4F1
# 3                                    De Culo  SOBNYVR12A8C13558C
# 4       Rene Ablaze Presents Winter Sessions  SOHSBXH12A8C13B0DF
# ...                                      ...                 ...
# 999995                          Pacha V.I.P.  SOTXAME12AB018F136
# 999996              Naale Baba Lassi Pee Gya  SOXQYIQ12A8C137FBB
# 999997       Dub_Connected: electronic music  SOHODZI12A8C137BB3
# 999998          The Trance Collection Vol. 2  SOLXGOR12A81C21EB7
# 999999                            So Oder So  SOWXJXQ12AB0189F43
#
#                                       title
# 0                              Silent Night
# 1                               Tanssi vaan
# 2                         No One Could Ever
# 3                             Si Vos Querés
# 4                          Tangle Of Aspens
# ...                                     ...
# 999995                      O Samba Da Vida
# 999996                         Jago Chhadeo
# 999997                              Novemba
# 999998                              Faraday
# 999999  Fernweh feat. Sektion Kuchikäschtli
#
# [1000000 rows x 5 columns]

# %% [markdown]
# Now we concatenat them

# %%
concatenated_df = pd.concat([analysis_df, musicbrainz_df, metadata_df], axis=1)
concatenated_df
# Out:
#                   track_id  year           artist_id       artist_name  \
# 0       TRMMMYQ128F932D901  2003  ARYZTJS1187B98C555  Faster Pussy cat
# 1       TRMMMKD128F425225D  1995  ARMVN3U1187FB3A1EB  Karkkiautomaatti
# 2       TRMMMRX128F93187D9  2006  ARGEKB01187FB50750    Hudson Mohawke
# 3       TRMMMCH128F425532C  2003  ARNWYLR1187B9B2F9C       Yerba Brava
# 4       TRMMMWA128F426B589     0  AREQDTE1269FB37231        Der Mystic
# ...                    ...   ...                 ...               ...
# 999995  TRYYYUS12903CD2DF0     0  AR7Z4J81187FB3FC59      Kiko Navarro
# 999996  TRYYYJO128F426DA37     0  ART5FZD1187B9A7FCF     Kuldeep Manak
# 999997  TRYYYMG128F4260ECA     0  ARZ3R6M1187B9AF750    Gabriel Le Mar
# 999998  TRYYYDJ128F9310A21     0  ARCMCOK1187B9B1073             Elude
# 999999  TRYYYVU12903CD01E3  2004  AR7PLM21187B990D08             Texta
#
#                                      release             song_id  \
# 0                      Monster Ballads X-Mas  SOQMMHC12AB0180CB8
# 1                                Karkuteillä  SOVFVAK12A8C1350D9
# 2                                     Butter  SOGTUKN12AB017F4F1
# 3                                    De Culo  SOBNYVR12A8C13558C
# 4       Rene Ablaze Presents Winter Sessions  SOHSBXH12A8C13B0DF
# ...                                      ...                 ...
# 999995                          Pacha V.I.P.  SOTXAME12AB018F136
# 999996              Naale Baba Lassi Pee Gya  SOXQYIQ12A8C137FBB
# 999997       Dub_Connected: electronic music  SOHODZI12A8C137BB3
# 999998          The Trance Collection Vol. 2  SOLXGOR12A81C21EB7
# 999999                            So Oder So  SOWXJXQ12AB0189F43
#
#                                       title    artist_location  \
# 0                              Silent Night
# 1                               Tanssi vaan
# 2                         No One Could Ever  Glasgow, Scotland
# 3                             Si Vos Querés
# 4                          Tangle Of Aspens
# ...                                     ...                ...
# 999995                      O Samba Da Vida
# 999996                         Jago Chhadeo
# 999997                              Novemba            GERMANY
# 999998                              Faraday
# 999999  Fernweh feat. Sektion Kuchikäschtli
#
#         artist_latitude  artist_longitude
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2               55.8578          -4.24251
# 3                   NaN               NaN
# 4                   NaN               NaN
# ...                 ...               ...
# 999995              NaN               NaN
# 999996              NaN               NaN
# 999997              NaN               NaN
# 999998              NaN               NaN
# 999999              NaN               NaN
#
# [1000000 rows x 10 columns]

# %% [markdown]
# # MSDI dataset

# %%
# Read the msdi dataset
input_msdi_path = "input/MSDI_dataset"
df = pd.read_csv(f"{input_msdi_path}/MSD-I_dataset.tsv", sep='\t', header=0)
print(df.count())

# Remove duplicates

df_unique = df.drop_duplicates(subset='album_index')
print("-------- after duplicates deletion --------")
print(df_unique.count())
# Out:
# msd_track_id     30713
# genre            30713
# album_index      30713
# set              30713
# msd_artist_id    30713
# image_url        30713
# dtype: int64
# -------- after duplicates deletion --------
# msd_track_id     16753
# genre            16753
# album_index      16753
# set              16753
# msd_artist_id    16753
# image_url        16753
# dtype: int64

# %%
df_unique
# Out:
#              msd_track_id       genre  album_index    set       msd_artist_id  \
# 0      TRABKJU128F422A7FE       Metal            0  train  ARBD4QW1187FB42153
# 1      TRBLDQQ128F92E58B4        Rock            1  train  AR3RK011187FB3CE3B
# 2      TRDMMDE128F14A9052        Rock            2  train  ARJVTRE1187B9959C0
# 3      TRJOPZB128F4250E02        Rock            4  train  AR62BB21187B9AC83D
# 4      TRJKBVL128F935567B        Rock            5  train  AR7GVOV1187B9B5FF1
# ...                   ...         ...          ...    ...                 ...
# 30701  TRKHBDC12903CD8949  Electronic        22332   test  ARGSRW21187B992282
# 30702  TRDGJQT128F42632E3  Electronic        22337   test  ARJH2B61187B9B9465
# 30703  TRRESAT128F422A1E6  Electronic        22347   test  ARON0ER1187FB52E2A
# 30707  TRMFLQB12903CE56C2       Blues        22358   test  AR56P361187B9AC4DB
# 30709  TRJUGOK128F4243DA6         Pop        22364   test  AR5MK521187B98E0B8
#
#                                                image_url
# 0      http://artwork-cdn.7static.com/static/img/slee...
# 1      http://artwork-cdn.7static.com/static/img/slee...
# 2      http://artwork-cdn.7static.com/static/img/slee...
# 3      http://artwork-cdn.7static.com/static/img/slee...
# 4      http://artwork-cdn.7static.com/static/img/slee...
# ...                                                  ...
# 30701  http://artwork-cdn.7static.com/static/img/slee...
# 30702  http://artwork-cdn.7static.com/static/img/slee...
# 30703  http://artwork-cdn.7static.com/static/img/slee...
# 30707  http://artwork-cdn.7static.com/static/img/slee...
# 30709  http://artwork-cdn.7static.com/static/img/slee...
#
# [16753 rows x 6 columns]

# %%
# Download images
#save_msdi_images_from_dataframe(f"{input_msdi_path}/images_msdi", df_unique)

# %%
df_unique
# Out:
#              msd_track_id       genre  album_index    set       msd_artist_id  \
# 0      TRABKJU128F422A7FE       Metal            0  train  ARBD4QW1187FB42153
# 1      TRBLDQQ128F92E58B4        Rock            1  train  AR3RK011187FB3CE3B
# 2      TRDMMDE128F14A9052        Rock            2  train  ARJVTRE1187B9959C0
# 3      TRJOPZB128F4250E02        Rock            4  train  AR62BB21187B9AC83D
# 4      TRJKBVL128F935567B        Rock            5  train  AR7GVOV1187B9B5FF1
# ...                   ...         ...          ...    ...                 ...
# 16748  TRKHBDC12903CD8949  Electronic        22332   test  ARGSRW21187B992282
# 16749  TRDGJQT128F42632E3  Electronic        22337   test  ARJH2B61187B9B9465
# 16750  TRRESAT128F422A1E6  Electronic        22347   test  ARON0ER1187FB52E2A
# 16751  TRMFLQB12903CE56C2       Blues        22358   test  AR56P361187B9AC4DB
# 16752  TRJUGOK128F4243DA6         Pop        22364   test  AR5MK521187B98E0B8
#
#                                                image_url  \
# 0      http://artwork-cdn.7static.com/static/img/slee...
# 1      http://artwork-cdn.7static.com/static/img/slee...
# 2      http://artwork-cdn.7static.com/static/img/slee...
# 3      http://artwork-cdn.7static.com/static/img/slee...
# 4      http://artwork-cdn.7static.com/static/img/slee...
# ...                                                  ...
# 16748  http://artwork-cdn.7static.com/static/img/slee...
# 16749  http://artwork-cdn.7static.com/static/img/slee...
# 16750  http://artwork-cdn.7static.com/static/img/slee...
# 16751  http://artwork-cdn.7static.com/static/img/slee...
# 16752  http://artwork-cdn.7static.com/static/img/slee...
#
#                          name_image            track_id  year  \
# 0          0_TRABKJU128F422A7FE.png  TRABKJU128F422A7FE  2006
# 1          1_TRBLDQQ128F92E58B4.png  TRBLDQQ128F92E58B4  2007
# 2          2_TRDMMDE128F14A9052.png  TRDMMDE128F14A9052  1981
# 3          4_TRJOPZB128F4250E02.png  TRJOPZB128F4250E02  2002
# 4          5_TRJKBVL128F935567B.png  TRJKBVL128F935567B  1990
# ...                             ...                 ...   ...
# 16748  22332_TRKHBDC12903CD8949.png  TRKHBDC12903CD8949     0
# 16749  22337_TRDGJQT128F42632E3.png  TRDGJQT128F42632E3  2004
# 16750  22347_TRRESAT128F422A1E6.png  TRRESAT128F422A1E6     0
# 16751  22358_TRMFLQB12903CE56C2.png  TRMFLQB12903CE56C2  2001
# 16752  22364_TRJUGOK128F4243DA6.png  TRJUGOK128F4243DA6  1996
#
#                 artist_id    artist_name  \
# 0      ARBD4QW1187FB42153  Scar Symmetry
# 1      AR3RK011187FB3CE3B   Eddie Vedder
# 2      ARJVTRE1187B9959C0         Foghat
# 3      AR62BB21187B9AC83D   The Breeders
# 4      AR7GVOV1187B9B5FF1        Sebadoh
# ...                   ...            ...
# 16748  ARGSRW21187B992282     Lazybatusu
# 16749  ARJH2B61187B9B9465    Funk D'Void
# 16750  ARON0ER1187FB52E2A        Arrakis
# 16751  AR56P361187B9AC4DB     Gary Moore
# 16752  AR5MK521187B98E0B8      Heaven 17
#
#                                           release             song_id  \
# 0                     Nuclear Blast Showdown 2006  SODUYOC12A67ADC8ED
# 1      Music For The Motion Picture Into The Wild  SODUDJI12A8C141513
# 2                Girls To Chat And Boys To Bounce  SODUUHR12A6D4FB01C
# 3                                        Title Tk  SODUEZB12A8C1348D5
# 4                                             III  SODURCL12A81358260
# ...                                           ...                 ...
# 16748                                  Lazybatusu  SOFLHUI12A58A7DDD4
# 16749                                volume freak  SOFLOYC12A8C13730A
# 16750                                   The Spice  SOFLBCB12A6D4FC865
# 16751                           Back To The Blues  SOFLPHC12A58A76A02
# 16752                         Bigger Than America  SOOMIPU12A8BEE956D
#
#                       title                 artist_location  artist_latitude  \
# 0           The Illusionist                          Sweden         62.19845
# 1                  Tuolumne  Etats-Unis, Illinois, Evanston         42.05665
# 2            Weekend Driver                 London, England         40.71455
# 3                 Too Alive                          Boston         42.31256
# 4      Ride The Darker Wave                     Amherst, MA         42.37522
# ...                     ...                             ...              ...
# 16748             Keepin On                        New York              NaN
# 16749               Endless               Glasgow, Scotland         55.85780
# 16750             The Spice                              FR         46.71067
# 16751   Picture Of The Moon       Belfast, Northern Ireland         54.59580
# 16752      Another Big Idea                 London, England         51.50632
#
#        artist_longitude country
# 0              17.55142      SE
# 1             -87.68659      US
# 2             -74.00712      US
# 3             -71.08868      US
# 4             -72.51984      US
# ...                 ...     ...
# 16748               NaN     NaN
# 16749          -4.24251      GB
# 16750           1.71819      FR
# 16751          -5.93494      GB
# 16752          -0.12714      GB
#
# [16753 rows x 18 columns]

# %%
# Add image name to a new column in dataframe
name = []
for index, row in df_unique.iterrows():
    track_name = row['msd_track_id']
    album_index = row['album_index']
    name.append( f"{album_index}_{track_name}.png")
df_unique['name_image'] = name

# %% [markdown]
# ### Joining with MSD

# %%
df_joined = pd.merge(left=df_unique, right=concatenated_df, left_on='msd_track_id', right_on='track_id', how='left')

# %%
df_joined
# Out:
#              msd_track_id       genre  album_index    set       msd_artist_id  \
# 0      TRABKJU128F422A7FE       Metal            0  train  ARBD4QW1187FB42153
# 1      TRBLDQQ128F92E58B4        Rock            1  train  AR3RK011187FB3CE3B
# 2      TRDMMDE128F14A9052        Rock            2  train  ARJVTRE1187B9959C0
# 3      TRJOPZB128F4250E02        Rock            4  train  AR62BB21187B9AC83D
# 4      TRJKBVL128F935567B        Rock            5  train  AR7GVOV1187B9B5FF1
# ...                   ...         ...          ...    ...                 ...
# 16748  TRKHBDC12903CD8949  Electronic        22332   test  ARGSRW21187B992282
# 16749  TRDGJQT128F42632E3  Electronic        22337   test  ARJH2B61187B9B9465
# 16750  TRRESAT128F422A1E6  Electronic        22347   test  ARON0ER1187FB52E2A
# 16751  TRMFLQB12903CE56C2       Blues        22358   test  AR56P361187B9AC4DB
# 16752  TRJUGOK128F4243DA6         Pop        22364   test  AR5MK521187B98E0B8
#
#                                                image_url  \
# 0      http://artwork-cdn.7static.com/static/img/slee...
# 1      http://artwork-cdn.7static.com/static/img/slee...
# 2      http://artwork-cdn.7static.com/static/img/slee...
# 3      http://artwork-cdn.7static.com/static/img/slee...
# 4      http://artwork-cdn.7static.com/static/img/slee...
# ...                                                  ...
# 16748  http://artwork-cdn.7static.com/static/img/slee...
# 16749  http://artwork-cdn.7static.com/static/img/slee...
# 16750  http://artwork-cdn.7static.com/static/img/slee...
# 16751  http://artwork-cdn.7static.com/static/img/slee...
# 16752  http://artwork-cdn.7static.com/static/img/slee...
#
#                          name_image            track_id  year  \
# 0          0_TRABKJU128F422A7FE.png  TRABKJU128F422A7FE  2006
# 1          1_TRBLDQQ128F92E58B4.png  TRBLDQQ128F92E58B4  2007
# 2          2_TRDMMDE128F14A9052.png  TRDMMDE128F14A9052  1981
# 3          4_TRJOPZB128F4250E02.png  TRJOPZB128F4250E02  2002
# 4          5_TRJKBVL128F935567B.png  TRJKBVL128F935567B  1990
# ...                             ...                 ...   ...
# 16748  22332_TRKHBDC12903CD8949.png  TRKHBDC12903CD8949     0
# 16749  22337_TRDGJQT128F42632E3.png  TRDGJQT128F42632E3  2004
# 16750  22347_TRRESAT128F422A1E6.png  TRRESAT128F422A1E6     0
# 16751  22358_TRMFLQB12903CE56C2.png  TRMFLQB12903CE56C2  2001
# 16752  22364_TRJUGOK128F4243DA6.png  TRJUGOK128F4243DA6  1996
#
#                 artist_id    artist_name  \
# 0      ARBD4QW1187FB42153  Scar Symmetry
# 1      AR3RK011187FB3CE3B   Eddie Vedder
# 2      ARJVTRE1187B9959C0         Foghat
# 3      AR62BB21187B9AC83D   The Breeders
# 4      AR7GVOV1187B9B5FF1        Sebadoh
# ...                   ...            ...
# 16748  ARGSRW21187B992282     Lazybatusu
# 16749  ARJH2B61187B9B9465    Funk D'Void
# 16750  ARON0ER1187FB52E2A        Arrakis
# 16751  AR56P361187B9AC4DB     Gary Moore
# 16752  AR5MK521187B98E0B8      Heaven 17
#
#                                           release             song_id  \
# 0                     Nuclear Blast Showdown 2006  SODUYOC12A67ADC8ED
# 1      Music For The Motion Picture Into The Wild  SODUDJI12A8C141513
# 2                Girls To Chat And Boys To Bounce  SODUUHR12A6D4FB01C
# 3                                        Title Tk  SODUEZB12A8C1348D5
# 4                                             III  SODURCL12A81358260
# ...                                           ...                 ...
# 16748                                  Lazybatusu  SOFLHUI12A58A7DDD4
# 16749                                volume freak  SOFLOYC12A8C13730A
# 16750                                   The Spice  SOFLBCB12A6D4FC865
# 16751                           Back To The Blues  SOFLPHC12A58A76A02
# 16752                         Bigger Than America  SOOMIPU12A8BEE956D
#
#                       title                 artist_location  artist_latitude  \
# 0           The Illusionist                          Sweden         62.19845
# 1                  Tuolumne  Etats-Unis, Illinois, Evanston         42.05665
# 2            Weekend Driver                 London, England         40.71455
# 3                 Too Alive                          Boston         42.31256
# 4      Ride The Darker Wave                     Amherst, MA         42.37522
# ...                     ...                             ...              ...
# 16748             Keepin On                        New York              NaN
# 16749               Endless               Glasgow, Scotland         55.85780
# 16750             The Spice                              FR         46.71067
# 16751   Picture Of The Moon       Belfast, Northern Ireland         54.59580
# 16752      Another Big Idea                 London, England         51.50632
#
#        artist_longitude
# 0              17.55142
# 1             -87.68659
# 2             -74.00712
# 3             -71.08868
# 4             -72.51984
# ...                 ...
# 16748               NaN
# 16749          -4.24251
# 16750           1.71819
# 16751          -5.93494
# 16752          -0.12714
#
# [16753 rows x 17 columns]

# %%
df_joined['country'] = df_joined.apply(LocationProcessor.get_country_from_coordinates, axis=1)

# %%
df_joined['country_name'] = df_joined['country'].apply(LocationProcessor.get_country_name)

df_joined['artist_location_country'] = df_joined.apply(
    lambda row: LocationProcessor.get_artist_country_name(row['artist_location']) if pd.isna(row['country_name']) else row['country_name'],
    axis=1
)
df_joined['artist_location_country'] = df_joined['artist_location_country'].apply(LocationProcessor.get_country_post_processing)
# Out:
#              msd_track_id       genre  album_index    set       msd_artist_id  \
# 0      TRABKJU128F422A7FE       Metal            0  train  ARBD4QW1187FB42153
# 1      TRBLDQQ128F92E58B4        Rock            1  train  AR3RK011187FB3CE3B
# 2      TRDMMDE128F14A9052        Rock            2  train  ARJVTRE1187B9959C0
# 3      TRJOPZB128F4250E02        Rock            4  train  AR62BB21187B9AC83D
# 4      TRJKBVL128F935567B        Rock            5  train  AR7GVOV1187B9B5FF1
# ...                   ...         ...          ...    ...                 ...
# 16748  TRKHBDC12903CD8949  Electronic        22332   test  ARGSRW21187B992282
# 16749  TRDGJQT128F42632E3  Electronic        22337   test  ARJH2B61187B9B9465
# 16750  TRRESAT128F422A1E6  Electronic        22347   test  ARON0ER1187FB52E2A
# 16751  TRMFLQB12903CE56C2       Blues        22358   test  AR56P361187B9AC4DB
# 16752  TRJUGOK128F4243DA6         Pop        22364   test  AR5MK521187B98E0B8
#
#                                                image_url  \
# 0      http://artwork-cdn.7static.com/static/img/slee...
# 1      http://artwork-cdn.7static.com/static/img/slee...
# 2      http://artwork-cdn.7static.com/static/img/slee...
# 3      http://artwork-cdn.7static.com/static/img/slee...
# 4      http://artwork-cdn.7static.com/static/img/slee...
# ...                                                  ...
# 16748  http://artwork-cdn.7static.com/static/img/slee...
# 16749  http://artwork-cdn.7static.com/static/img/slee...
# 16750  http://artwork-cdn.7static.com/static/img/slee...
# 16751  http://artwork-cdn.7static.com/static/img/slee...
# 16752  http://artwork-cdn.7static.com/static/img/slee...
#
#                          name_image            track_id  year  \
# 0          0_TRABKJU128F422A7FE.png  TRABKJU128F422A7FE  2006
# 1          1_TRBLDQQ128F92E58B4.png  TRBLDQQ128F92E58B4  2007
# 2          2_TRDMMDE128F14A9052.png  TRDMMDE128F14A9052  1981
# 3          4_TRJOPZB128F4250E02.png  TRJOPZB128F4250E02  2002
# 4          5_TRJKBVL128F935567B.png  TRJKBVL128F935567B  1990
# ...                             ...                 ...   ...
# 16748  22332_TRKHBDC12903CD8949.png  TRKHBDC12903CD8949     0
# 16749  22337_TRDGJQT128F42632E3.png  TRDGJQT128F42632E3  2004
# 16750  22347_TRRESAT128F422A1E6.png  TRRESAT128F422A1E6     0
# 16751  22358_TRMFLQB12903CE56C2.png  TRMFLQB12903CE56C2  2001
# 16752  22364_TRJUGOK128F4243DA6.png  TRJUGOK128F4243DA6  1996
#
#                 artist_id    artist_name  \
# 0      ARBD4QW1187FB42153  Scar Symmetry
# 1      AR3RK011187FB3CE3B   Eddie Vedder
# 2      ARJVTRE1187B9959C0         Foghat
# 3      AR62BB21187B9AC83D   The Breeders
# 4      AR7GVOV1187B9B5FF1        Sebadoh
# ...                   ...            ...
# 16748  ARGSRW21187B992282     Lazybatusu
# 16749  ARJH2B61187B9B9465    Funk D'Void
# 16750  ARON0ER1187FB52E2A        Arrakis
# 16751  AR56P361187B9AC4DB     Gary Moore
# 16752  AR5MK521187B98E0B8      Heaven 17
#
#                                           release             song_id  \
# 0                     Nuclear Blast Showdown 2006  SODUYOC12A67ADC8ED
# 1      Music For The Motion Picture Into The Wild  SODUDJI12A8C141513
# 2                Girls To Chat And Boys To Bounce  SODUUHR12A6D4FB01C
# 3                                        Title Tk  SODUEZB12A8C1348D5
# 4                                             III  SODURCL12A81358260
# ...                                           ...                 ...
# 16748                                  Lazybatusu  SOFLHUI12A58A7DDD4
# 16749                                volume freak  SOFLOYC12A8C13730A
# 16750                                   The Spice  SOFLBCB12A6D4FC865
# 16751                           Back To The Blues  SOFLPHC12A58A76A02
# 16752                         Bigger Than America  SOOMIPU12A8BEE956D
#
#                       title                 artist_location  artist_latitude  \
# 0           The Illusionist                          Sweden         62.19845
# 1                  Tuolumne  Etats-Unis, Illinois, Evanston         42.05665
# 2            Weekend Driver                 London, England         40.71455
# 3                 Too Alive                          Boston         42.31256
# 4      Ride The Darker Wave                     Amherst, MA         42.37522
# ...                     ...                             ...              ...
# 16748             Keepin On                        New York              NaN
# 16749               Endless               Glasgow, Scotland         55.85780
# 16750             The Spice                              FR         46.71067
# 16751   Picture Of The Moon       Belfast, Northern Ireland         54.59580
# 16752      Another Big Idea                 London, England         51.50632
#
#        artist_longitude  country
# 0              17.55142      NaN
# 1             -87.68659      NaN
# 2             -74.00712      NaN
# 3             -71.08868      NaN
# 4             -72.51984      NaN
# ...                 ...      ...
# 16748               NaN      NaN
# 16749          -4.24251      NaN
# 16750           1.71819      NaN
# 16751          -5.93494      NaN
# 16752          -0.12714      NaN
#
# [16753 rows x 18 columns]

# %%
df_joined.to_csv(f"{input_msdi_path}/msdi_mapping_and_metadata.csv", index=False)

# %% [markdown]
# ## Stats

# %%
df_joined = pd.read_csv(f'{input_msdi_path}/msdi_mapping_and_metadata.csv', header=0)

# %% [markdown]
# ### Genre distribution
# Genre distribution, the most common genre in this data set is Rock with 23.22% of the images, followed by Electronic (15.19%) and Pop (10.98%)

# %%
value_counts = df_joined['genre'].value_counts()
value_counts_df = value_counts.reset_index()
value_counts_df['Percentage'] = round((value_counts_df['count'] * 100) / 16753, 3)
value_counts_df
# Out:
#          genre  count  Percentage
# 0         Rock   3890      23.220
# 1   Electronic   2544      15.185
# 2          Pop   1840      10.983
# 3         Jazz   1341       8.005
# 4          Rap   1232       7.354
# 5        Metal   1140       6.805
# 6          RnB    970       5.790
# 7       Reggae    829       4.948
# 8      Country    802       4.787
# 9         Folk    541       3.229
# 10       Blues    420       2.507
# 11        Punk    391       2.334
# 12       Latin    381       2.274
# 13       World    280       1.671
# 14     New Age    152       0.907

# %% [markdown]
# We have 63 different release year and approximately for 10% of the data there's not release year

# %%
year_counts = df_joined['year'].value_counts()
year_counts_df = year_counts.reset_index()
year_counts_df['Percentage'] = round((year_counts_df['count'] * 100) / len(df_final), 3)
year_counts_df
# Out:
#     year  count  Percentage
# 0      0   3078       9.857
# 1   2007   1191       3.814
# 2   2006   1071       3.430
# 3   2005   1016       3.254
# 4   2008    965       3.090
# ..   ...    ...         ...
# 59  1958      1       0.003
# 60  1929      1       0.003
# 61  1935      1       0.003
# 62  1956      1       0.003
# 63  1942      1       0.003
#
# [64 rows x 3 columns]

# %% [markdown]
# There's a even distribution of artists there are 8858 different artists, the most repeated one is Celine Dion

# %%
artirst_counts = df_joined['artist_id'].value_counts()
artirst_counts_df = artirst_counts.reset_index()
artirst_counts_df['Percentage'] = round((artirst_counts_df['count'] * 100) / len(df_final), 3)
artirst_counts_df = pd.merge(left=artirst_counts_df, right=df_joined, left_on='artist_id', right_on='artist_id', how='left').drop_duplicates(subset='artist_id')
artirst_counts_df= artirst_counts_df[['artist_id','artist_name','count','Percentage']]
artirst_counts_df
# Out:
#                 artist_id         artist_name  count  Percentage
# 0      ARFWL8S1187B9B4B44         Céline Dion     19       0.061
# 19     ARZZ5ZR1187FB4D149                 Air     17       0.054
# 36     ARNF13I1187FB562A5      Massive Attack     17       0.054
# 53     AR0IU4L1187FB4CCB9       Atomic Kitten     15       0.048
# 68     AR9I1L41187FB37F0E  Harry Connick_ Jr.     15       0.048
# ...                   ...                 ...    ...         ...
# 16748  AREXUHA1187B9923BF  Empire State Human      1       0.003
# 16749  ARDY3451187B9A0226       Skeeter Davis      1       0.003
# 16750  ARFCK201187FB469B3       Dennis Coffey      1       0.003
# 16751  AR6WICD1187B998708   Christian McBride      1       0.003
# 16752  AR5MK521187B98E0B8           Heaven 17      1       0.003
#
# [8858 rows x 4 columns]

# %% [markdown]
# We have the artist location of the album for almost 60% of the data, this is 10230 images

# %%
artist_location_counts = df_joined['artist_location_country'].value_counts()
artist_location_counts_df = artist_location_counts.reset_index()
artist_location_counts_df['Percentage'] = round((artist_location_counts_df['count'] * 100) / len(df_joined), 3)
artist_location_counts_df
# Out:
#     artist_location_country  count  Percentage
# 0                       n/a   6523      38.936
# 1             United States   4643      27.714
# 2            United Kingdom   1669       9.962
# 3                    Canada    719       4.292
# 4                    Sweden    259       1.546
# ..                      ...    ...         ...
# 119                  Uganda      1       0.006
# 120               Hong Kong      1       0.006
# 121                 Burundi      1       0.006
# 122           Côte d'Ivoire      1       0.006
# 123                   Benin      1       0.006
#
# [124 rows x 3 columns]

# %% [markdown]
# ### Images stats
# The size of the images are 200x200

# %%
folder_path = f"{input_msdi_path}/images_msdi"
unique_dimensions = set()
resolutions = []

for filename in os.listdir(folder_path):

    file_path = os.path.join(folder_path, filename)

    if file_path.lower().endswith(('.png')):
        try:
            # Open the image and get its dimensions
            with Image.open(file_path) as img:
                width, height = img.size
                # Add the dimensions to the set
                unique_dimensions.add((width, height))
                dpi = img.info.get('dpi', None)
                if dpi:
                    resolutions.append(dpi)
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# %%
tuple_counts = Counter(resolutions)
print(f"Number of images with available defined {len(resolutions)}")
print(f"Dimension of images {unique_dimensions}")
# Out:
# Number of images with resolution defined 14287
# Dimension of images {(200, 200)}

# %%
resolutions_data = [(k[0], k[1], v) for k, v in tuple_counts.items()]
resolution_df = pd.DataFrame(resolutions_data, columns=['x', 'y', 'count'])
resolution_df = resolution_df.sort_values('count', ascending=False)
resolution_df['Percentage'] = round((resolution_df['count'] * 100) / len(resolutions), 3)
resolution_df
# Out:
#        x     y  count  Percentage
# 0    300   300   8030      56.205
# 1     72    72   4174      29.215
# 2     96    96   1868      13.075
# 5    200   200     64       0.448
# 7    100   100     54       0.378
# 9    150   150     18       0.126
# 17   600   600     11       0.077
# 4    762   762     10       0.070
# 15   400   400      8       0.056
# 18     6     6      8       0.056
# 3    304   304      6       0.042
# 8    299   299      4       0.028
# 21   180   180      4       0.028
# 27    97    97      2       0.014
# 13   760   760      2       0.014
# 6   1200  1200      2       0.014
# 11  5000  5000      2       0.014
# 10    90    90      1       0.007
# 35   298   298      1       0.007
# 34   360   360      1       0.007
# 33    44    44      1       0.007
# 32   357   357      1       0.007
# 31   110   110      1       0.007
# 30   250   250      1       0.007
# 29     3     3      1       0.007
# 28    50    50      1       0.007
# 23    82    82      1       0.007
# 26   301   301      1       0.007
# 25   838   838      1       0.007
# 24    93    93      1       0.007
# 22   289   289      1       0.007
# 20   303   303      1       0.007
# 19   199   199      1       0.007
# 16   330   330      1       0.007
# 14     1     1      1       0.007
# 12   119   119      1       0.007
# 36   350   350      1       0.007
